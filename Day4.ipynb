# %%
import pandas as pd

# Load with error handling
df = pd.read_csv("broken-csv.txt", on_bad_lines="skip")

# %%
print(df.head())
# Out:
#    id                 name                                email signup_date  \
# 0   1         Ada Lovelace                      ada@example.org  2026-01-04
# 1   2  Linus Torvalds, Jr.                    linus@example.com  2026-01-05
# 2   3         Grace Hopper                    grace@example.org  2026-01-06
# 3   4  Margaret "Hamilton"                 margaret@example.com  2026-01-07
# 4   5          Alan Turing  alan@example.com,backup@example.com  2026-01-08
#
#     age
# 0  38.0
# 1  54.0
# 2  41.0
# 3  32.0
# 4  29.0

# %%
print("First rows:\n", df.head())
# Out:
# First rows:
#     id                 name                                email signup_date  \
# 0   1         Ada Lovelace                      ada@example.org  2026-01-04
# 1   2  Linus Torvalds, Jr.                    linus@example.com  2026-01-05
# 2   3         Grace Hopper                    grace@example.org  2026-01-06
# 3   4  Margaret "Hamilton"                 margaret@example.com  2026-01-07
# 4   5          Alan Turing  alan@example.com,backup@example.com  2026-01-08
#
#     age
# 0  38.0
# 1  54.0
# 2  41.0
# 3  32.0
# 4  29.0

# %%
print("Columns:\n", df.columns)
# Out:
# Columns:
#  Index(['id', 'name', 'email', 'signup_date', 'age'], dtype='str')

# %%
print("Info:\n")
df.info()
# Out:
# Info:
#
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10 non-null     int64
#  1   name         10 non-null     str
#  2   email        10 non-null     str
#  3   signup_date  10 non-null     str
#  4   age          9 non-null      float64
# dtypes: float64(1), int64(1), str(3)
# memory usage: 532.0 bytes

# %%
print("Statistics:\n", df.describe())
# Out:
# Statistics:
#               id        age
# count  10.00000   9.000000
# mean    5.50000  42.555556
# std     3.02765  14.875408
# min     1.00000  28.000000
# 25%     3.25000  32.000000
# 50%     5.50000  38.000000
# 75%     7.75000  54.000000
# max    10.00000  71.000000

# %%
print("Shape:", df.shape)   # rows, columns
# Out:
# Shape: (10, 5)
