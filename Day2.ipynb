# %%
# Integer
students = 50

# Float
average_score = 87.5

# String
course = "Data Science Internship"

# Boolean
completed = False

# List
marks = [85, 90, 78, 92]

# Dictionary

student = {"name": "Pavan", "age": 20, "course": "CS"}
print(student)
print(course)
# Out:
# {'name': 'Pavan', 'age': 20, 'course': 'CS'}
# Data Science Internship

# %%
# Arithmetic
print("Addition:", 10 + 5)
print("Division:", 10 / 2)

# Comparison
print("Is 10 greater than 5?", 10 > 5)

# Logical
x, y = True, False
print("AND:", x and y)
print("OR:", x or y)
# Out:
# Addition: 15
# Division: 5.0
# Is 10 greater than 5? True
# AND: False
# OR: True

# %%
# For loop
for subject in ["Maths", "Physics", "Chemistry"]:
    print("Studying:", subject)

# While loop
count = 1
while count <= 3:
    print("Attempt:", count)
    count += 1
# Out:
# Studying: Maths
# Studying: Physics
# Studying: Chemistry
# Attempt: 1
# Attempt: 2
# Attempt: 3

# %%
def square(num):
    return num * num

def introduce(name, course="Python"):
    return f"My name is {name}, I am learning {course}."

print(square(4))
print(introduce("Praveen"))
# Out:
# 16
# My name is Praveen, I am learning Python.
